# %%
# !pip install langchain 
# !pip install langchain-community
# !pip install chromadb
# !pip install pypdf
# !pip install pytest
# Out:
# Requirement already satisfied: langchain in /venv/main/lib/python3.10/site-packages (0.3.19)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /venv/main/lib/python3.10/site-packages (from langchain) (3.11.13)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.35 in /venv/main/lib/python3.10/site-packages (from langchain) (0.3.40)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /venv/main/lib/python3.10/site-packages (from langchain) (2.10.6)
# Requirement already satisfied: numpy<2,>=1.26.4 in /venv/main/lib/python3.10/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /venv/main/lib/python3.10/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /venv/main/lib/python3.10/site-packages (from langchain) (0.3.11)
# Requirement already satisfied: requests<3,>=2 in /venv/main/lib/python3.10/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /venv/main/lib/python3.10/site-packages (from langchain) (2.0.38)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /venv/main/lib/python3.10/site-packages (from langchain) (9.0.0)
# Requirement already satisfied: PyYAML>=5.3 in /venv/main/lib/python3.10/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in /venv/main/lib/python3.10/site-packages (from langchain) (0.3.6)
# Requirement already satisfied: multidict<7.0,>=4.5 in /venv/main/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /venv/main/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.6)
# Requirement already satisfied: propcache>=0.2.0 in /venv/main/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /venv/main/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /venv/main/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: attrs>=17.3.0 in /venv/main/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (25.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /venv/main/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /venv/main/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.35->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /venv/main/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.35->langchain) (4.12.2)
# Requirement already satisfied: packaging<25,>=23.2 in /venv/main/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.35->langchain) (24.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /venv/main/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /venv/main/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /venv/main/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /venv/main/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /venv/main/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /venv/main/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /venv/main/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /venv/main/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /venv/main/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: idna<4,>=2.5 in /venv/main/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: greenlet!=0.4.17 in /venv/main/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in /venv/main/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /venv/main/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /venv/main/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /venv/main/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.35->langchain) (3.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /venv/main/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in /venv/main/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Collecting langchain-community
#   Downloading langchain_community-0.3.18-py3-none-any.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 21.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy<2,>=1.26.4 in /venv/main/lib/python3.10/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /venv/main/lib/python3.10/site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: PyYAML>=5.3 in /venv/main/lib/python3.10/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /venv/main/lib/python3.10/site-packages (from langchain-community) (0.3.11)
# Requirement already satisfied: langchain<1.0.0,>=0.3.19 in /venv/main/lib/python3.10/site-packages (from langchain-community) (0.3.19)
# Requirement already satisfied: requests<3,>=2 in /venv/main/lib/python3.10/site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.37 in /venv/main/lib/python3.10/site-packages (from langchain-community) (0.3.40)
# Collecting pydantic-settings<3.0.0,>=2.4.0
#   Downloading pydantic_settings-2.8.1-py3-none-any.whl (30 kB)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /venv/main/lib/python3.10/site-packages (from langchain-community) (2.0.38)
# Collecting dataclasses-json<0.7,>=0.5.7
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /venv/main/lib/python3.10/site-packages (from langchain-community) (3.11.13)
# Collecting httpx-sse<1.0.0,>=0.4.0
#   Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /venv/main/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /venv/main/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /venv/main/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /venv/main/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /venv/main/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /venv/main/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /venv/main/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Requirement already satisfied: attrs>=17.3.0 in /venv/main/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.1.0)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 KB 3.9 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /venv/main/lib/python3.10/site-packages (from langchain<1.0.0,>=0.3.19->langchain-community) (2.10.6)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in /venv/main/lib/python3.10/site-packages (from langchain<1.0.0,>=0.3.19->langchain-community) (0.3.6)
# Requirement already satisfied: packaging<25,>=23.2 in /venv/main/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (24.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /venv/main/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /venv/main/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (4.12.2)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /venv/main/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /venv/main/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /venv/main/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /venv/main/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.15)
# Requirement already satisfied: python-dotenv>=0.21.0 in /venv/main/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /venv/main/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /venv/main/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /venv/main/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /venv/main/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: greenlet!=0.4.17 in /venv/main/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in /venv/main/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /venv/main/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /venv/main/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /venv/main/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.37->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /venv/main/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.19->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /venv/main/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.19->langchain-community) (2.27.2)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: sniffio>=1.1 in /venv/main/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /venv/main/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.2.2)
# Installing collected packages: mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-community-0.3.18 marshmallow-3.26.1 mypy-extensions-1.0.0 pydantic-settings-2.8.1 typing-inspect-0.9.0
# Requirement already satisfied: chromadb in /venv/main/lib/python3.10/site-packages (0.6.3)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /venv/main/lib/python3.10/site-packages (from chromadb) (0.51b0)
# Requirement already satisfied: mmh3>=4.0.1 in /venv/main/lib/python3.10/site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: tqdm>=4.65.0 in /venv/main/lib/python3.10/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: tenacity>=8.2.3 in /venv/main/lib/python3.10/site-packages (from chromadb) (9.0.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /venv/main/lib/python3.10/site-packages (from chromadb) (1.30.0)
# Requirement already satisfied: posthog>=2.4.0 in /venv/main/lib/python3.10/site-packages (from chromadb) (3.18.0)
# Requirement already satisfied: typer>=0.9.0 in /venv/main/lib/python3.10/site-packages (from chromadb) (0.15.2)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /venv/main/lib/python3.10/site-packages (from chromadb) (0.34.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /venv/main/lib/python3.10/site-packages (from chromadb) (1.30.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /venv/main/lib/python3.10/site-packages (from chromadb) (0.21.0)
# Requirement already satisfied: fastapi>=0.95.2 in /venv/main/lib/python3.10/site-packages (from chromadb) (0.115.11)
# Requirement already satisfied: numpy>=1.22.5 in /venv/main/lib/python3.10/site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: overrides>=7.3.1 in /venv/main/lib/python3.10/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: build>=1.0.3 in /venv/main/lib/python3.10/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: rich>=10.11.0 in /venv/main/lib/python3.10/site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: onnxruntime>=1.14.1 in /venv/main/lib/python3.10/site-packages (from chromadb) (1.20.1)
# Requirement already satisfied: orjson>=3.9.12 in /venv/main/lib/python3.10/site-packages (from chromadb) (3.10.15)
# Requirement already satisfied: kubernetes>=28.1.0 in /venv/main/lib/python3.10/site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: httpx>=0.27.0 in /venv/main/lib/python3.10/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /venv/main/lib/python3.10/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /venv/main/lib/python3.10/site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /venv/main/lib/python3.10/site-packages (from chromadb) (1.30.0)
# Requirement already satisfied: pypika>=0.48.9 in /venv/main/lib/python3.10/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: PyYAML>=6.0.0 in /venv/main/lib/python3.10/site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: grpcio>=1.58.0 in /venv/main/lib/python3.10/site-packages (from chromadb) (1.70.0)
# Requirement already satisfied: pydantic>=1.9 in /venv/main/lib/python3.10/site-packages (from chromadb) (2.10.6)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /venv/main/lib/python3.10/site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: importlib-resources in /venv/main/lib/python3.10/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: tomli>=1.1.0 in /venv/main/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (2.2.1)
# Requirement already satisfied: pyproject_hooks in /venv/main/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: packaging>=19.1 in /venv/main/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (24.2)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /venv/main/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb) (0.46.0)
# Requirement already satisfied: anyio in /venv/main/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /venv/main/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: certifi in /venv/main/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (2025.1.31)
# Requirement already satisfied: idna in /venv/main/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /venv/main/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /venv/main/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: urllib3>=1.24.2 in /venv/main/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.3.0)
# Requirement already satisfied: six>=1.9.0 in /venv/main/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: requests in /venv/main/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: google-auth>=1.0.1 in /venv/main/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: requests-oauthlib in /venv/main/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /venv/main/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: python-dateutil>=2.5.3 in /venv/main/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: durationpy>=0.7 in /venv/main/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: coloredlogs in /venv/main/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: protobuf in /venv/main/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.3)
# Requirement already satisfied: flatbuffers in /venv/main/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: sympy in /venv/main/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: deprecated>=1.2.6 in /venv/main/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /venv/main/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Requirement already satisfied: opentelemetry-proto==1.30.0 in /venv/main/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.30.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.30.0 in /venv/main/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.30.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /venv/main/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.68.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.51b0 in /venv/main/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.51b0 in /venv/main/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.51b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in /venv/main/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.51b0)
# Requirement already satisfied: opentelemetry-util-http==0.51b0 in /venv/main/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.51b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /venv/main/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in /venv/main/lib/python3.10/site-packages (from opentelemetry-instrumentation-asgi==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in /venv/main/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: monotonic>=1.5 in /venv/main/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: distro>=1.5.0 in /venv/main/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /venv/main/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /venv/main/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (2.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /venv/main/lib/python3.10/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /venv/main/lib/python3.10/site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /venv/main/lib/python3.10/site-packages (from tokenizers>=0.13.2->chromadb) (0.28.1)
# Requirement already satisfied: click>=8.0.0 in /venv/main/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /venv/main/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /venv/main/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in /venv/main/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.4)
# Requirement already satisfied: python-dotenv>=0.13 in /venv/main/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /venv/main/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /venv/main/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /venv/main/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /venv/main/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /venv/main/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /venv/main/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.2.0)
# Requirement already satisfied: filelock in /venv/main/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.17.0)
# Requirement already satisfied: zipp>=3.20 in /venv/main/lib/python3.10/site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /venv/main/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /venv/main/lib/python3.10/site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.1)
# Requirement already satisfied: sniffio>=1.1 in /venv/main/lib/python3.10/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /venv/main/lib/python3.10/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.2)
# Requirement already satisfied: humanfriendly>=9.1 in /venv/main/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /venv/main/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /venv/main/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: pypdf in /venv/main/lib/python3.10/site-packages (5.3.0)
# Requirement already satisfied: typing_extensions>=4.0 in /venv/main/lib/python3.10/site-packages (from pypdf) (4.12.2)
# Requirement already satisfied: pytest in /venv/main/lib/python3.10/site-packages (8.3.4)
# Requirement already satisfied: iniconfig in /venv/main/lib/python3.10/site-packages (from pytest) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /venv/main/lib/python3.10/site-packages (from pytest) (1.5.0)
# Requirement already satisfied: tomli>=1 in /venv/main/lib/python3.10/site-packages (from pytest) (2.2.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /venv/main/lib/python3.10/site-packages (from pytest) (1.2.2)
# Requirement already satisfied: packaging in /venv/main/lib/python3.10/site-packages (from pytest) (24.2)

# %% [markdown]
# # PDF

# %%
from langchain.document_loaders.pdf import PyPDFDirectoryLoader

def load_documents():
    document_loader = PyPDFDirectoryLoader('data')
    return document_loader.load()

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.schema.document import Document

def split_documents(documents: list[Document]):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=800,
        chunk_overlap=80,
        length_function=len,
        is_separator_regex=False,
    )
    return text_splitter.split_documents(documents)

# %%
documents = load_documents()
chunks = split_documents(documents)

# %%
from langchain_community.embeddings.ollama import OllamaEmbeddings

def get_embedding_function():
    embeddings = OllamaEmbeddings(model="nomic-embed-text")
    return embeddings
